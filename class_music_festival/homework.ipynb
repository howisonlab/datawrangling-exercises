# %%
%LOAD postgresql host=localhost dbname=class_music_festival

# %% [markdown]
# Q1. what is the capacity of the BMI venue?

# %%
SELECT *
FROM venues

# %%
SELECT *
FROM venues
WHERE name = 'BMI'

# %%
SELECT venues.capacity
FROM venues
WHERE name = 'BMI'
# Out:
# +----------+
# | capacity |
# +----------+
# | 2000     |
# +----------+
# 1 row in set (0.00 sec)

# %%
SELECT *
FROM tickets 
WHERE tickets.ticketnum = 'TA2080128'
# Out:
# +----+-------+-----------+----------------+-------------+
# | id | price | ticketnum | performance_id | purchase_id |
# +----+-------+-----------+----------------+-------------+
# | 22 | 48    | TA2080128 | 48             | 3           |
# +----+-------+-----------+----------------+-------------+
# 1 row in set (0.00 sec)
